# %% [markdown]
# ## we are officially in vector space now

# %%
import numpy as np

# %%
data = np.load("subject_embeddings.npz", allow_pickle=True)
print("Keys inside file:", data.files)
print("Embeddings shape:", data["embeddings"].shape)
print("Subject codes:", data["codes"])
# Out:
# Keys inside file: ['embeddings', 'codes']
# Embeddings shape: (9, 384)
# Subject codes: ['PROJ-CS-600' 'BHM-MC-009' 'BCS-DS-611' 'BCS-DS-613' 'BCS-DS-659'
#  'BCS-DS-802' 'BCS-DS-851' 'BCS-DS-635' 'BCS-DS-684']

# %%
print(data['embeddings'][0].shape)
# Out:
# (384,)
